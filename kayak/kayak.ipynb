# %%
# Librairies imports
from geopy.geocoders import Nominatim
import pandas as pd
from openmeteo_py import Hourly,Daily,Options,OWmanager
import boto3
import plotly.express as px
import secret_code_AWS as sec
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import psycopg2
import folium

# %%
# CONSTANTS
BUCKET_NAME = "pascal-kayak"

# %% [markdown]
# #### CITIES DataFrame construction with :
# - a unique id (as primary key for the futur database) : id
# - city name : name (from the initial list)
# - city latitude : lat (from Nomibatim API)
# - city longitude : lon (from Nomibatim API)
# - weather score : weather_score (from Open Meteo API, 100 minus the mean of weathercode from 9AM to 18PM during the next 8 days)

# %% [markdown]
# #### CITIES DataFrame construction

# %%
#
# Constructing the cities dataframe with an id and the name from the list given
#
cities = [
    "Mont Saint Michel",
    "St Malo",
    "Bayeux",
    "Le Havre",
    "Rouen",
    "Paris",
    "Amiens",
    "Lille",
    "Strasbourg",
    "Chateau du Haut Koenigsbourg",
    "Colmar",
    "Eguisheim",
    "Besancon",
    "Dijon",
    "Annecy",
    "Grenoble",
    "Lyon",
    "Gorges du Verdon",
    "Bormes les Mimosas",
    "Cassis",
    "Marseille",
    "Aix en Provence",
    "Avignon",
    "Uzes",
    "Nimes",
    "Aigues Mortes",
    "Saintes Maries de la mer",
    "Collioure",
    "Carcassonne",
    "Ariege",
    "Toulouse",
    "Montauban",
    "Biarritz",
    "Bayonne",
    "La Rochelle",
]
# consruct a dataframe for all the cities with their index
dict_cities = {
    "id": [i + 1 for i in range(len(cities))],
    "name": cities,
    
}

df_cities = pd.DataFrame.from_dict(dict_cities)
df_cities
# Out:
#     id                          name
# 0    1             Mont Saint Michel
# 1    2                       St Malo
# 2    3                        Bayeux
# 3    4                      Le Havre
# 4    5                         Rouen
# 5    6                         Paris
# 6    7                        Amiens
# 7    8                         Lille
# 8    9                    Strasbourg
# 9   10  Chateau du Haut Koenigsbourg
# 10  11                        Colmar
# 11  12                     Eguisheim
# 12  13                      Besancon
# 13  14                         Dijon
# 14  15                        Annecy
# 15  16                      Grenoble
# 16  17                          Lyon
# 17  18              Gorges du Verdon
# 18  19            Bormes les Mimosas
# 19  20                        Cassis
# 20  21                     Marseille
# 21  22               Aix en Provence
# 22  23                       Avignon
# 23  24                          Uzes
# 24  25                         Nimes
# 25  26                 Aigues Mortes
# 26  27      Saintes Maries de la mer
# 27  28                     Collioure
# 28  29                   Carcassonne
# 29  30                        Ariege
# 30  31                      Toulouse
# 31  32                     Montauban
# 32  33                      Biarritz
# 33  34                       Bayonne
# 34  35                   La Rochelle

# %% [markdown]
# #### Define the cities geolocation with Nominatim API

# %%
#
# Fuction giving the latitude and longitude from a city name
# using the Nominatim Geo Localisation API
#
def lat_lon(city):
    loc = Nominatim(user_agent="GetLoc")

    getLoc = loc.geocode(city)

    # printing address
    print(getLoc.address)

    return (getLoc.latitude, getLoc.longitude)

# %%
#
# Constructing 2 colums of latitude and longitude for each city in the dataframe
#
list_lat = []
list_lon = []
for city in df_cities["name"]:
    tmp_lat_lon = lat_lon(city)
    list_lat.append(tmp_lat_lon[0])
    list_lon.append(tmp_lat_lon[1])
df_cities["lat"] = list_lat
df_cities["lon"] = list_lon
df_cities
# Out:
# Mont Saint-Michel, Plateforme du Saut-­Gaultier, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France
# Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35400, France
# Bayeux, Calvados, Normandie, France métropolitaine, 14400, France
# Le Havre, Seine-Maritime, Normandie, France métropolitaine, France
# Rouen, Seine-Maritime, Normandie, France métropolitaine, France
# Paris, Île-de-France, France métropolitaine, France
# Amiens, Somme, Hauts-de-France, France métropolitaine, France
# Lille, Nord, Hauts-de-France, France métropolitaine, France
# Strasbourg, Bas-Rhin, Grand Est, France métropolitaine, France
# Château du Haut-Kœnigsbourg, Chemin fermé suite  à travaux, Château du Haut-Kœnigsbourg, Orschwiller, Sélestat-Erstein, Bas-Rhin, Grand Est, France métropolitaine, 67600, France
# Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68000, France
# Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68420, France
# Besançon, Doubs, Bourgogne-Franche-Comté, France métropolitaine, 25000, France
# Dijon, Côte-d'Or, Bourgogne-Franche-Comté, France métropolitaine, 21000, France
# Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, France métropolitaine, France
# Grenoble, Isère, Auvergne-Rhône-Alpes, France métropolitaine, France
# Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France
# Gorges du Verdon, Route de la Maline, Les Ferrailles, La Palud-sur-Verdon, Castellane, Alpes-de-Haute-Provence, Provence-Alpes-Côte d'Azur, France métropolitaine, 04120, France
# Bormes-les-Mimosas, Toulon, Var, Provence-Alpes-Côte d'Azur, France métropolitaine, 83230, France
# Cassis, Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13260, France
# Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13000, France
# Aix-en-Provence, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, France
# Avignon, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, France
# Uzès, Nîmes, Gard, Occitanie, France métropolitaine, 30700, France
# Nîmes, Gard, Occitanie, France métropolitaine, France
# Aigues-Mortes, Nîmes, Gard, Occitanie, France métropolitaine, 30220, France
# Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13460, France
# Collioure, Céret, Pyrénées-Orientales, Occitanie, France métropolitaine, 66190, France
# Carcassonne, Aude, Occitanie, France métropolitaine, 11000, France
# Ariège, Occitanie, France métropolitaine, France
# Toulouse, Haute-Garonne, Occitanie, France métropolitaine, France
# Montauban, Tarn-et-Garonne, Occitanie, France métropolitaine, 82000, France
# Biarritz, Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64200, France
# Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64100, France
# La Rochelle, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17000, France
#     id                          name        lat       lon
# 0    1             Mont Saint Michel  48.635954 -1.511460
# 1    2                       St Malo  48.649518 -2.026041
# 2    3                        Bayeux  49.276462 -0.702474
# 3    4                      Le Havre  49.493898  0.107973
# 4    5                         Rouen  49.440459  1.093966
# 5    6                         Paris  48.858890  2.320041
# 6    7                        Amiens  49.894171  2.295695
# 7    8                         Lille  50.636565  3.063528
# 8    9                    Strasbourg  48.584614  7.750713
# 9   10  Chateau du Haut Koenigsbourg  48.249490  7.344296
# 10  11                        Colmar  48.077752  7.357964
# 11  12                     Eguisheim  48.044797  7.307962
# 12  13                      Besancon  47.238022  6.024362
# 13  14                         Dijon  47.321581  5.041470
# 14  15                        Annecy  45.899235  6.128885
# 15  16                      Grenoble  45.187560  5.735782
# 16  17                          Lyon  45.757814  4.832011
# 17  18              Gorges du Verdon  43.749656  6.328562
# 18  19            Bormes les Mimosas  43.150697  6.341928
# 19  20                        Cassis  43.214036  5.539632
# 20  21                     Marseille  43.296174  5.369953
# 21  22               Aix en Provence  43.529842  5.447474
# 22  23                       Avignon  43.949249  4.805901
# 23  24                          Uzes  44.012128  4.419672
# 24  25                         Nimes  43.837425  4.360069
# 25  26                 Aigues Mortes  43.565823  4.191284
# 26  27      Saintes Maries de la mer  43.452277  4.428717
# 27  28                     Collioure  42.525050  3.083155
# 28  29                   Carcassonne  43.213036  2.349107
# 29  30                        Ariege  42.945537  1.406554
# 30  31                      Toulouse  43.604462  1.444247
# 31  32                     Montauban  44.017584  1.354999
# 32  33                      Biarritz  43.471144 -1.552727
# 33  34                       Bayonne  43.494514 -1.473666
# 34  35                   La Rochelle  46.159113 -1.152043

# %% [markdown]
# #### Define the cities weather with Open Meteo API

# %%
#
# function to retrieve meteo data from Open Meteo API for the next 8 days for a geo localisation
#
def meteo(latitude, longitude):

    hourly = Hourly()
    daily = Daily()
    options = Options(latitude,longitude)

    mgr = OWmanager(options,
        hourly.all(),
        daily.all())

    return mgr.get_data()

# %%
#
# Calculating and storing the Weather Score for each city
#

# intialize the list to store the mean weather score for each cities
list_score_weather = []

# taking the meteo data for each cities
for i in df_cities.index:

    # retreving data from Open Meteo API
    meteo_city = meteo(df_cities['lat'][i], df_cities['lon'][i])

    # keeping the data hour per hour in a dataframe
    df_meteo = pd.DataFrame.from_dict(meteo_city["hourly"])

    # constructing a colonne only with hours (the 5 last characters)
    df_meteo["hour"] = df_meteo.apply(lambda row : row["time"][-5:], axis = 1)

    # kepping only meteo data in the day hours (from 9AM to 18PM)
    mask_day_hours = (df_meteo["hour"] > "08:00") & (df_meteo["hour"] < "19:00")
    df_meteo = df_meteo.loc[mask_day_hours, ["weathercode"]]

    # defining the score_weather by substracting the average weather code 
    # from 9AM to 18PM to 100 to have the greatest number for the good weather
    list_score_weather.append(100 - df_meteo["weathercode"].mean())


# adding the lists of meteo data into the cities dataframe
df_cities["score_weather"] = list_score_weather
df_cities
# Out:
#     id                          name        lat       lon  score_weather
# 0    1             Mont Saint Michel  48.635954 -1.511460      92.985714
# 1    2                       St Malo  48.649518 -2.026041      92.871429
# 2    3                        Bayeux  49.276462 -0.702474      98.028571
# 3    4                      Le Havre  49.493898  0.107973      97.042857
# 4    5                         Rouen  49.440459  1.093966      96.242857
# 5    6                         Paris  48.858890  2.320041      94.314286
# 6    7                        Amiens  49.894171  2.295695      92.728571
# 7    8                         Lille  50.636565  3.063528      97.442857
# 8    9                    Strasbourg  48.584614  7.750713      88.614286
# 9   10  Chateau du Haut Koenigsbourg  48.249490  7.344296      81.300000
# 10  11                        Colmar  48.077752  7.357964      84.985714
# 11  12                     Eguisheim  48.044797  7.307962      80.514286
# 12  13                      Besancon  47.238022  6.024362      86.642857
# 13  14                         Dijon  47.321581  5.041470      95.371429
# 14  15                        Annecy  45.899235  6.128885      95.900000
# 15  16                      Grenoble  45.187560  5.735782      98.657143
# 16  17                          Lyon  45.757814  4.832011      96.242857
# 17  18              Gorges du Verdon  43.749656  6.328562      99.714286
# 18  19            Bormes les Mimosas  43.150697  6.341928      99.385714
# 19  20                        Cassis  43.214036  5.539632      99.785714
# 20  21                     Marseille  43.296174  5.369953      99.728571
# 21  22               Aix en Provence  43.529842  5.447474      99.900000
# 22  23                       Avignon  43.949249  4.805901      99.628571
# 23  24                          Uzes  44.012128  4.419672      99.571429
# 24  25                         Nimes  43.837425  4.360069      99.700000
# 25  26                 Aigues Mortes  43.565823  4.191284      99.685714
# 26  27      Saintes Maries de la mer  43.452277  4.428717      99.642857
# 27  28                     Collioure  42.525050  3.083155      99.757143
# 28  29                   Carcassonne  43.213036  2.349107      99.342857
# 29  30                        Ariege  42.945537  1.406554      99.885714
# 30  31                      Toulouse  43.604462  1.444247      96.542857
# 31  32                     Montauban  44.017584  1.354999      95.328571
# 32  33                      Biarritz  43.471144 -1.552727      97.485714
# 33  34                       Bayonne  43.494514 -1.473666      97.414286
# 34  35                   La Rochelle  46.159113 -1.152043      91.671429

# %%
#
# saving the cities dataframe to a csv file
#
df_cities.to_csv('cities.csv', index=False)

# %% [markdown]
# #### Upload the Cities and Hotels CSV files in a AWS S3 Bucket

# %%
# Opening a AWS session with SECRET IDs from the secret_code file
session = boto3.Session(aws_access_key_id=sec.AWS_ACCESS_KEY_ID, 
                        aws_secret_access_key=sec.AWS_SECRET_ACCESS_KEY)
# Creating a S3 bucket to store the csv files
s3 = session.resource("s3")

s3.meta.client.upload_file('./cities.csv', BUCKET_NAME, 'cities.csv')
# Uploading the csv file for the hotels scrapped with scrappy
s3.meta.client.upload_file('./hotels.csv', BUCKET_NAME, 'hotels.csv')

# %% [markdown]
# #### Download the Cities and Hotels CSV Files from the AWS S3 Bucket and storing them in a RDS Postgre DataBase
# - the cities data will be a table
# - the hotels data will be a table (without the city_name, useless because of the hotel_id)

# %%
# Downloading the CSV Files from the AWS S3 Bucket stored in a specifique folder (csv_from_aws)
session = boto3.Session(aws_access_key_id=sec.AWS_ACCESS_KEY_ID, 
                        aws_secret_access_key=sec.AWS_SECRET_ACCESS_KEY)

session.resource('s3').Bucket(BUCKET_NAME).download_file('cities.csv','./csv_from_aws/cities.csv')
session.resource('s3').Bucket(BUCKET_NAME).download_file('hotels.csv','./csv_from_aws/hotels.csv')

# %%
df_cities = pd.read_csv('./csv_from_aws/cities.csv')
df_hotels = pd.read_csv('./csv_from_aws/hotels.csv')
print(df_cities.head())
print(df_hotels.head())
# Out:
#    id               name        lat       lon  score_weather
# 0   1  Mont Saint Michel  48.635954 -1.511460      92.985714
# 1   2            St Malo  48.649518 -2.026041      92.871429
# 2   3             Bayeux  49.276462 -0.702474      98.028571
# 3   4           Le Havre  49.493898  0.107973      97.042857
# 4   5              Rouen  49.440459  1.093966      96.242857
#    city_id   city_name                                        name  \
# 0        7      Amiens                       WHITE HOUSE DHAVERNAS
# 1        9  Strasbourg  Carpe Diem Home - Au pied de la Cathédrale
# 2        6       Paris      Citadines Saint-Germain-des-Prés Paris
# 3        3      Bayeux                          LOGIS DU GRAND PIN
# 4        8       Lille                  Novotel Lille Centre Gares
#
#                                         booking_link  score        lat  \
# 0  https://www.booking.com/hotel/fr/white-house-d...    8.7  49.881470
# 1  https://www.booking.com/hotel/fr/carpe-diem-ho...    9.5  48.582077
# 2  https://www.booking.com/hotel/fr/citadines-apa...    8.1  48.854926
# 3  https://www.booking.com/hotel/fr/logis-du-gran...    9.5  49.252004
# 4  https://www.booking.com/hotel/fr/novotel-lille...    8.0  50.634441
#
#         lon                                              descr
# 0  2.299871  Situé à Amiens, en Picardie, à proximité de la...
# 1  7.749161  Proposant des hébergements avec une cuisine, l...
# 2  2.341155  Le Citadines Saint-Germain-des-Prés Paris béné...
# 3 -0.669848  Offrant une vue sur le jardin, le LOGIS DU GRA...
# 4  3.073358  Situé à seulement 300 mètres de la gare de Lil...

# %%
#
# Deleting the tables CITIES and HOTELS if they already exist
#
dbconnection = psycopg2.connect(
   database="postgres", user=sec.RDS_USERNAME, password=sec.RDS_PASSWORD, host=sec.RDS_HOSTNAME, port= '5432'
)
cursor = dbconnection.cursor()

#Dropping EMPLOYEE table if already exists
cursor.execute("DROP TABLE IF EXISTS CITIES")
print("Table CITIES dropped")

cursor.execute("DROP TABLE IF EXISTS HOTELS")
print("Table HOTELS dropped")

#Commit your changes in the database
dbconnection.commit()

#Closing the connection
dbconnection.close()
# Out:
# Table CITIES dropped
# Table HOTELS dropped

# %%
#
# dropping the city_name column from the hotels dataframe to avoid duplicate data (the city name already in in the CITIES table and can be join with the city_id)
#
df_hotels = df_hotels.drop(columns="city_name")
df_hotels.head()
# Out:
#    city_id                                        name  \
# 0        7                       WHITE HOUSE DHAVERNAS
# 1        9  Carpe Diem Home - Au pied de la Cathédrale
# 2        6      Citadines Saint-Germain-des-Prés Paris
# 3        3                          LOGIS DU GRAND PIN
# 4        8                  Novotel Lille Centre Gares
#
#                                         booking_link  score        lat  \
# 0  https://www.booking.com/hotel/fr/white-house-d...    8.7  49.881470
# 1  https://www.booking.com/hotel/fr/carpe-diem-ho...    9.5  48.582077
# 2  https://www.booking.com/hotel/fr/citadines-apa...    8.1  48.854926
# 3  https://www.booking.com/hotel/fr/logis-du-gran...    9.5  49.252004
# 4  https://www.booking.com/hotel/fr/novotel-lille...    8.0  50.634441
#
#         lon                                              descr
# 0  2.299871  Situé à Amiens, en Picardie, à proximité de la...
# 1  7.749161  Proposant des hébergements avec une cuisine, l...
# 2  2.341155  Le Citadines Saint-Germain-des-Prés Paris béné...
# 3 -0.669848  Offrant une vue sur le jardin, le LOGIS DU GRA...
# 4  3.073358  Situé à seulement 300 mètres de la gare de Lil...

# %%
# Creating a session to store the csv files on the postgresql RDS database
engine = create_engine(f"postgresql+psycopg2://{sec.RDS_USERNAME}:{sec.RDS_PASSWORD}@{sec.RDS_HOSTNAME}/postgres", echo=True)
Session = sessionmaker(bind=engine)
df_cities.to_sql("cities", engine, index=False)
df_hotels.to_sql("hotels", engine, index=False)
# Out:
# 2023-01-30 09:19:33,094 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-01-30 09:19:33,096 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:33,108 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-01-30 09:19:33,110 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:33,122 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-01-30 09:19:33,124 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:33,138 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:33,139 INFO sqlalchemy.engine.Engine [generated in 0.00117s] {'name': 'cities'}
# 2023-01-30 09:19:33,159 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-01-30 09:19:33,161 INFO sqlalchemy.engine.Engine
# CREATE TABLE cities (
# 	id BIGINT,
# 	name TEXT,
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	score_weather FLOAT(53)
# )
#
#
# 2023-01-30 09:19:33,162 INFO sqlalchemy.engine.Engine [no key 0.00109s] {}
# 2023-01-30 09:19:33,185 INFO sqlalchemy.engine.Engine COMMIT
# 2023-01-30 09:19:33,195 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-01-30 09:19:33,197 INFO sqlalchemy.engine.Engine INSERT INTO cities (id, name, lat, lon, score_weather) VALUES (%(id)s, %(name)s, %(lat)s, %(lon)s, %(score_weather)s)
# 2023-01-30 09:19:33,198 INFO sqlalchemy.engine.Engine [generated in 0.00169s] ({'id': 1, 'name': 'Mont Saint Michel', 'lat': 48.6359541, 'lon': -1.511459954959514, 'score_weather': 92.98571428571428}, {'id': 2, 'name': 'St Malo', 'lat': 48.649518, 'lon': -2.0260409, 'score_weather': 92.87142857142857}, {'id': 3, 'name': 'Bayeux', 'lat': 49.2764624, 'lon': -0.7024738, 'score_weather': 98.02857142857142}, {'id': 4, 'name': 'Le Havre', 'lat': 49.4938975, 'lon': 0.1079732, 'score_weather': 97.04285714285714}, {'id': 5, 'name': 'Rouen', 'lat': 49.4404591, 'lon': 1.0939658, 'score_weather': 96.24285714285716}, {'id': 6, 'name': 'Paris', 'lat': 48.8588897, 'lon': 2.3200410217200766, 'score_weather': 94.31428571428572}, {'id': 7, 'name': 'Amiens', 'lat': 49.8941708, 'lon': 2.2956951, 'score_weather': 92.72857142857144}, {'id': 8, 'name': 'Lille', 'lat': 50.6365654, 'lon': 3.0635282, 'score_weather': 97.44285714285716}  ... displaying 10 of 35 total bound parameter sets ...  {'id': 34, 'name': 'Bayonne', 'lat': 43.4945144, 'lon': -1.4736657, 'score_weather': 97.41428571428573}, {'id': 35, 'name': 'La Rochelle', 'lat': 46.1591126, 'lon': -1.1520434, 'score_weather': 91.67142857142858})
# 2023-01-30 09:19:33,212 INFO sqlalchemy.engine.Engine COMMIT
# 2023-01-30 09:19:33,222 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:33,224 INFO sqlalchemy.engine.Engine [cached since 0.08627s ago] {'name': 'hotels'}
# 2023-01-30 09:19:33,242 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-01-30 09:19:33,244 INFO sqlalchemy.engine.Engine
# CREATE TABLE hotels (
# 	city_id BIGINT,
# 	name TEXT,
# 	booking_link TEXT,
# 	score FLOAT(53),
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	descr TEXT
# )
#
#
# 2023-01-30 09:19:33,246 INFO sqlalchemy.engine.Engine [no key 0.00174s] {}
# 2023-01-30 09:19:33,261 INFO sqlalchemy.engine.Engine COMMIT
# 2023-01-30 09:19:33,269 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-01-30 09:19:33,274 INFO sqlalchemy.engine.Engine INSERT INTO hotels (city_id, name, booking_link, score, lat, lon, descr) VALUES (%(city_id)s, %(name)s, %(booking_link)s, %(score)s, %(lat)s, %(lon)s, %(descr)s)
# 2023-01-30 09:19:33,275 INFO sqlalchemy.engine.Engine [generated in 0.00442s] ({'city_id': 7, 'name': 'WHITE HOUSE DHAVERNAS', 'booking_link': 'https://www.booking.com/hotel/fr/white-house-dhavernas.fr.html', 'score': 8.7, 'lat': 49.8814696, 'lon': 2.2998714, 'descr': "Situé à Amiens, en Picardie, à proximité de la gare et du musée Berny, le WHITE HOUSE DHAVERNAS propose des hébergements avec connexion Wi-Fi et park ... (486 characters truncated) ...  jardins flottants. L'aéroport le plus proche, celui de Beauvais-Tillé, est situé à 64 km. Un service de navette aéroport est assuré gratuitement. \n"}, {'city_id': 9, 'name': 'Carpe Diem Home - Au pied de la Cathédrale', 'booking_link': 'https://www.booking.com/hotel/fr/carpe-diem-home.fr.html', 'score': 9.5, 'lat': 48.582077, 'lon': 7.749161, 'descr': 'Proposant des hébergements avec une cuisine, le Carpe Diem Home est installé à 1 minute à pied de la cathédrale de Strasbourg et à 700 mètres du quar ... (255 characters truncated) ... ejoindrez le Parlement européen en 15 minutes de route, le musée alsacien à 450 mètres et l’aéroport international de Strasbourg-Entzheim à 12 km. \n'}, {'city_id': 6, 'name': 'Citadines Saint-Germain-des-Prés Paris', 'booking_link': 'https://www.booking.com/hotel/fr/citadines-aparthotel-saint-germain-des-pres.fr.html', 'score': 8.1, 'lat': 48.85492633, 'lon': 2.34115541, 'descr': "Le Citadines Saint-Germain-des-Prés Paris bénéficie d'un emplacement en centre-ville à 300 mètres de la station de métro Saint-Michel. Situé à 10 min ... (760 characters truncated) ...  situe à 600 mètres du musée du Louvre, ainsi qu'à 15 minutes de marche des jardins du Luxembourg et du Panthéon. La résidence possède un parking. \n"}, {'city_id': 3, 'name': 'LOGIS DU GRAND PIN', 'booking_link': 'https://www.booking.com/hotel/fr/logis-du-grand-pin.fr.html', 'score': 9.5, 'lat': 49.2520036, 'lon': -0.6698477, 'descr': "Offrant une vue sur le jardin, le LOGIS DU GRAND PIN est situé à Bayeux, à 4,1 km du musée de la Tapisserie de Bayeux. Vous bénéficierez gratuitement ... (463 characters truncated) ... ,7 km du musée Baron Gérard et à 5,9 km de la cathédrale Notre-Dame de Bayeux. L'aéroport de Caen-Carpiquet, le plus proche, est implanté à 24 km. \n"}, {'city_id': 8, 'name': 'Novotel Lille Centre Gares', 'booking_link': 'https://www.booking.com/hotel/fr/novotel-lille-centre-gares.fr.html', 'score': 8.0, 'lat': 50.63444099, 'lon': 3.07335824, 'descr': "Situé à seulement 300 mètres de la gare de Lille Flandres, l'hôtel 4 étoiles Novotel Lille Centre Gares se trouve à 5 minutes de marche du centre de  ... (651 characters truncated) ... eau Siècle est à moins de 15 minutes à pied.\nDeux enfants âgés de 16 ans maximum peuvent séjourner gratuitement dans la chambre de leurs parents. \n"}, {'city_id': 4, 'name': 'Les Gîtes du Monde , Appartements 2 chambres- 4 lits simples modulables en lits doubles', 'booking_link': 'https://www.booking.com/hotel/fr/les-gites-du-monde-au-havre.fr.html', 'score': 8.3, 'lat': 49.49962464, 'lon': 0.1310809, 'descr': "Situé au Havre, l'établissement Les Gites du Monde, Appartements une ou deux chambres propose des appartements indépendants à la décoration inspirée  ... (615 characters truncated) ... ut être préparé sur demande.\nLa plage du Havre est située à 2,9 km, et vous trouverez un parking public à moins de 300 mètres de l'établissement. \n"}, {'city_id': 4, 'name': 'Appartement Rénové, 100 m de la gare, 83 m2, 5 Pers, Confortable et Lumineux', 'booking_link': 'https://www.booking.com/hotel/fr/appartement-renove-100-m-de-la-gare-83-m2-5-pers-confortable-et-lumineux.fr.html', 'score': 8.7, 'lat': 49.4923644, 'lon': 0.1226079, 'descr': "Situé au Havre, à 2,3 km de la plage du Havre, à 1,4 km du Volcan et à 1,3 km de l'église Saint-Michel, l'Appartement Rénové, 100 mètres de la gare,  ... (476 characters truncated) ... 2 km de l'appartement témoin Perret et à 1,9 km de l'église Saint-Joseph. L'aéroport de Deauville-Normandie, le plus proche, est im ...
# 2023-01-30 09:19:33,437 INFO sqlalchemy.engine.Engine COMMIT
# 875

# %% [markdown]
# #### Load the Cities and Hotels Data into DataFrames from the RDS Database

# %%
sql = "SELECT id, name, lat, lon, score_weather FROM cities"

engine = create_engine(f"postgresql+psycopg2://{sec.RDS_USERNAME}:{sec.RDS_PASSWORD}@{sec.RDS_HOSTNAME}/postgres", echo=True)
Session = sessionmaker(bind=engine)
dbConnection = engine.connect()


# Reading the Cities Data
df_cities  = pd.read_sql(sql, dbConnection)


# Print the DataFrame
print(df_cities)


 
# Close the database connection
dbConnection.close()
# Out:
# 2023-01-30 09:19:33,537 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-01-30 09:19:33,538 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:33,550 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-01-30 09:19:33,550 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:33,562 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-01-30 09:19:33,563 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:33,576 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:33,576 INFO sqlalchemy.engine.Engine [generated in 0.00073s] {'name': 'SELECT id, name, lat, lon, score_weather FROM cities'}
# 2023-01-30 09:19:33,588 INFO sqlalchemy.engine.Engine SELECT id, name, lat, lon, score_weather FROM cities
# 2023-01-30 09:19:33,588 INFO sqlalchemy.engine.Engine [raw sql] {}
#     id                          name        lat       lon  score_weather
# 0    1             Mont Saint Michel  48.635954 -1.511460      92.985714
# 1    2                       St Malo  48.649518 -2.026041      92.871429
# 2    3                        Bayeux  49.276462 -0.702474      98.028571
# 3    4                      Le Havre  49.493898  0.107973      97.042857
# 4    5                         Rouen  49.440459  1.093966      96.242857
# 5    6                         Paris  48.858890  2.320041      94.314286
# 6    7                        Amiens  49.894171  2.295695      92.728571
# 7    8                         Lille  50.636565  3.063528      97.442857
# 8    9                    Strasbourg  48.584614  7.750713      88.614286
# 9   10  Chateau du Haut Koenigsbourg  48.249490  7.344296      81.300000
# 10  11                        Colmar  48.077752  7.357964      84.985714
# 11  12                     Eguisheim  48.044797  7.307962      80.514286
# 12  13                      Besancon  47.238022  6.024362      86.642857
# 13  14                         Dijon  47.321581  5.041470      95.371429
# 14  15                        Annecy  45.899235  6.128885      95.900000
# 15  16                      Grenoble  45.187560  5.735782      98.657143
# 16  17                          Lyon  45.757814  4.832011      96.242857
# 17  18              Gorges du Verdon  43.749656  6.328562      99.714286
# 18  19            Bormes les Mimosas  43.150697  6.341928      99.385714
# 19  20                        Cassis  43.214036  5.539632      99.785714
# 20  21                     Marseille  43.296174  5.369953      99.728571
# 21  22               Aix en Provence  43.529842  5.447474      99.900000
# 22  23                       Avignon  43.949249  4.805901      99.628571
# 23  24                          Uzes  44.012128  4.419672      99.571429
# 24  25                         Nimes  43.837425  4.360069      99.700000
# 25  26                 Aigues Mortes  43.565823  4.191284      99.685714
# 26  27      Saintes Maries de la mer  43.452277  4.428717      99.642857
# 27  28                     Collioure  42.525050  3.083155      99.757143
# 28  29                   Carcassonne  43.213036  2.349107      99.342857
# 29  30                        Ariege  42.945537  1.406554      99.885714
# 30  31                      Toulouse  43.604462  1.444247      96.542857
# 31  32                     Montauban  44.017584  1.354999      95.328571
# 32  33                      Biarritz  43.471144 -1.552727      97.485714
# 33  34                       Bayonne  43.494514 -1.473666      97.414286
# 34  35                   La Rochelle  46.159113 -1.152043      91.671429

# %% [markdown]
# #### Show the map of the cities

# %%
fig = px.scatter_mapbox(
        df_cities, 
        lat="lat", 
        lon="lon",
        text="name",
        hover_name="name",
        size="score_weather", 
        color="score_weather",
        width=1000,
        height=800,
        mapbox_style="open-street-map"
)

fig.show()

# %% [markdown]
# #### Choose the 5 top cities

# %%
# Selecting the 5 top cities regarding the best weather score
df_cities.sort_values(by="score_weather", ascending=False, inplace=True, ignore_index=True)
df_cities_good_weather = df_cities.loc[0:4, :]
df_cities_good_weather[["name", "score_weather"]].head(5)
# Out:
#               name  score_weather
# 0  Aix en Provence      99.900000
# 1           Ariege      99.885714
# 2           Cassis      99.785714
# 3        Collioure      99.757143
# 4        Marseille      99.728571

# %%
# variables to center the map on the 5 cities
lat_mean = df_cities_good_weather["lat"].mean()
lon_mean = df_cities_good_weather["lon"].mean()

# %%
# Connecting to the database 
engine = create_engine(f"postgresql+psycopg2://{sec.RDS_USERNAME}:{sec.RDS_PASSWORD}@{sec.RDS_HOSTNAME}/postgres", echo=True)
Session = sessionmaker(bind=engine)
dbConnection = engine.connect()

# for each top 5 city, taking the 20 best hotels
i = 0
for city_id in df_cities_good_weather["id"]:
    sql = f"""
    SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr
    FROM hotels h, cities c
    WHERE h.city_id = c.id
    AND  h.city_id = {city_id} ;
    """
    df = pd.read_sql(sql, dbConnection)
    df.sort_values(by="score", ascending=False, inplace=True, ignore_index=True)
    
    # building the 20 hotels dataframe
    if i == 0:
        df_hotels_good_weather = df.loc[:19,:]
    else:
        df = df.loc[:19,:]
        df_hotels_good_weather = pd.concat([df_hotels_good_weather, df], ignore_index=True)
    i += 1

# Close the database connection
dbConnection.close()
# Out:
# 2023-01-30 09:19:34,236 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-01-30 09:19:34,238 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,250 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-01-30 09:19:34,252 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,264 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-01-30 09:19:34,266 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,279 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:34,280 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {'name': '\n    SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr\n    FROM hotels h, cities c\n    WHERE h.city_id = c.id\n    AND  h.city_id = 22 ;\n    '}
# 2023-01-30 09:19:34,296 INFO sqlalchemy.engine.Engine
#     SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr
#     FROM hotels h, cities c
#     WHERE h.city_id = c.id
#     AND  h.city_id = 22 ;
#
# 2023-01-30 09:19:34,298 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,312 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:34,315 INFO sqlalchemy.engine.Engine [cached since 0.03576s ago] {'name': '\n    SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr\n    FROM hotels h, cities c\n    WHERE h.city_id = c.id\n    AND  h.city_id = 30 ;\n    '}
# 2023-01-30 09:19:34,323 INFO sqlalchemy.engine.Engine
#     SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr
#     FROM hotels h, cities c
#     WHERE h.city_id = c.id
#     AND  h.city_id = 30 ;
#
# 2023-01-30 09:19:34,325 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,335 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:34,337 INFO sqlalchemy.engine.Engine [cached since 0.05859s ago] {'name': '\n    SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr\n    FROM hotels h, cities c\n    WHERE h.city_id = c.id\n    AND  h.city_id = 20 ;\n    '}
# 2023-01-30 09:19:34,349 INFO sqlalchemy.engine.Engine
#     SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr
#     FROM hotels h, cities c
#     WHERE h.city_id = c.id
#     AND  h.city_id = 20 ;
#
# 2023-01-30 09:19:34,349 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,363 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:34,364 INFO sqlalchemy.engine.Engine [cached since 0.08481s ago] {'name': '\n    SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr\n    FROM hotels h, cities c\n    WHERE h.city_id = c.id\n    AND  h.city_id = 28 ;\n    '}
# 2023-01-30 09:19:34,369 INFO sqlalchemy.engine.Engine
#     SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr
#     FROM hotels h, cities c
#     WHERE h.city_id = c.id
#     AND  h.city_id = 28 ;
#
# 2023-01-30 09:19:34,370 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-01-30 09:19:34,381 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2023-01-30 09:19:34,382 INFO sqlalchemy.engine.Engine [cached since 0.1028s ago] {'name': '\n    SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr\n    FROM hotels h, cities c\n    WHERE h.city_id = c.id\n    AND  h.city_id = 21 ;\n    '}
# 2023-01-30 09:19:34,388 INFO sqlalchemy.engine.Engine
#     SELECT h.name, h.lat, h.lon, h.booking_link, h.score, h.descr
#     FROM hotels h, cities c
#     WHERE h.city_id = c.id
#     AND  h.city_id = 21 ;
#
# 2023-01-30 09:19:34,388 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
df_hotels_good_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          100 non-null    object
#  1   lat           100 non-null    float64
#  2   lon           100 non-null    float64
#  3   booking_link  100 non-null    object
#  4   score         100 non-null    float64
#  5   descr         100 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 4.8+ KB

# %%
df_hotels_good_weather[["name", "score"]].head(20)
# Out:
#                                                  name  score
# 0                           Les Suites du Cours & Spa    9.1
# 1                                N.8 LIFESTYLE SUITES    9.1
# 2   T2 classé 3 étoile au centre du quartier histo...    8.7
# 3            Aparthotel Adagio Aix-en-Provence Centre    8.4
# 4                                     Domaine Gaogaia    8.4
# 5                                      Hotel Cardinal    8.4
# 6                               Aquabella Hôtel & Spa    8.4
# 7                                     Hôtel Escaletto    8.3
# 8                                     Hôtel Le Mozart    8.3
# 9                   Renaissance Aix-en-Provence Hotel    8.2
# 10                                Les Quatre Dauphins    8.2
# 11          Appart Hypercentre CLIM 2chb QuartierChic    8.2
# 12                                      Hôtel Rotonde    8.1
# 13                       Hôtel Cézanne Boutique-Hôtel    8.1
# 14                        Hôtel Birdy by Happyculture    8.1
# 15        Séjours & Affaires Aix-en-Provence Mirabeau    8.0
# 16                                Hôtel des Augustins    8.0
# 17                                        Le Concorde    7.8
# 18  Grand Hôtel Roi René Aix en Provence Centre - ...    7.8
# 19                                    Hôtel de France    7.6

# %%
m = folium.Map(location=[lat_mean, lon_mean], zoom_start=8)

# %%
df_hotels_good_weather.apply(
    lambda row:folium.Marker(
        location=[row["lat"], 
        row["lon"]], 
        popup="<a href='" + row['booking_link'] + "'>" + row['name'] + "</a>" + " " + str(row['score']))
        .add_to(m), axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cd90a7dcbc4860479cf19c16cfee411 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cd90a7dcbc4860479cf19c16cfee411&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cd90a7dcbc4860479cf19c16cfee411 = L.map(
#                 &quot;map_1cd90a7dcbc4860479cf19c16cfee411&quot;,
#                 {
#                     center: [43.10212788, 4.1693535831213095],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f72fdf8f50a2ea836faa46e2a30aeb87 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1cd90a7dcbc4860479cf19c16cfee411);
#
#
#             var marker_b881243096c2e36da0236447c38c5aad = L.marker(
#                 [43.52697234, 5.44928754],
#                 {}
#             ).addTo(map_1cd90a7dcbc4860479cf19c16cfee411);
#
#
#         var popup_a4b55ade8eeab18aa458b98ca524cbd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_009a3a58b963822b18f574af7d49b54c = $(`&lt;div id=&quot;html_009a3a58b963822b18f574af7d49b54c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/les-suites-du-cours.fr.html&#x27;&gt;Les Suites du Cours &amp; Spa&lt;/a&gt; 9.1&lt;/div&gt;`)[0];
#                 popup_a4b55ade8eeab18aa458b98ca524cbd6.setContent(html_009a3a58b963822b18f574af7d49b54c);
#
#
#
#         marker_b881243096c2e36da0236447c38c5aad.bindPopup(popup_a4b55ade8eeab18aa458b98ca524cbd6)
#         ;
#
#
#
#
#             var marker_679b5ce58384fc0580a36989fda6f675 = L.marker(
#                 [43.529989, 5.45096],
#                 {}
#             ).addTo(map_1cd90a7dcbc4860479cf19c16cfee411);
#
#
#         var popup_76d87b772e2f76c74bd1b26bfa695012 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bfddfaa9c671a323bbbc184d0cd290d0 = $(`&lt;div id=&quot;html_bfddfaa9c671a323bbbc184d0cd290d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/n8-lifestyle-suites-aix-en-provence.fr.html&#x27;&gt;N.8 LIFESTYLE SUITES&lt;/a&gt; 9.1&lt;/div&gt;`)[0];
#                 popup_76d87b772e2f76c74bd1b26bfa695012.setContent(html_bfddfaa9c671a323bbbc184d0cd290d0);
#
#
#
#         marker_679b5ce58384fc0580a36989fda6f675.bindPopup(popup_76d87b772e2f76c74bd1b26bfa695012)
#         ;
#
#
#
#
#             var marker_976782b0bb38866c86e2f2d401ddb366 = L.marker(
#                 [43.52997889, 5.44973644],
#                 {}
#             ).addTo(map_1cd90a7dcbc4860479cf19c16cfee411);
#
#
#         var popup_369ae5e3d0810c48185cb8d2d10f6f62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6feb01fff1610baaee8cdadbcb277f9 = $(`&lt;div id=&quot;html_e6feb01fff1610baaee8cdadbcb277f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/t2-centre-ville-aix-en-provence.fr.html&#x27;&gt;T2 classé 3 étoile au centre du quartier historique&lt;/a&gt; 8.7&lt;/div&gt;`)[0];
#                 popup_369ae5e3d0810c48185cb8d2d10f6f62.setContent(html_e6feb01fff1610baaee8cdadbcb277f9);
#
#
#
#         marker_976782b0bb38866c86e2f2d401ddb366.bindPopup(popup_369ae5e3d0810c48185cb8d2d10f6f62)
#         ;
#
#
#
#
#             var marker_afdd224d41fc9860a0cb539f9766b0c6 = L.marker(
#                 [43.52890621, 5.44086903],
#                 {}
#             ).addTo(map_1cd90a7dcbc4860479cf19c16cfee411);
#
#
#         var popup_30252c7b1dfeb168f83b02a1d1f1dae4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e4e54e4a0ec117df6e3b847c8287303 = $(`&lt;div id=&quot;html_3e4e54e4a0ec117df6e3b847c8287303&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/pierre-vacances-city-centre.fr.html&#x27;&gt;Aparthotel Adagio Aix-en-Provence Centre&lt;/a&gt; 8.4&lt;/div&gt;`)[0];
#                 popup_30252c7b1dfeb168f83b02a1d1f1dae4.setContent(html_3e4e54e4a0ec117df6e3b847c8287303);
#
#
#
#         marker_afdd224d41fc9860a0cb539f9766b0c6.bindPopup(popup_30252c7b1dfeb168f83b02a1d1f1dae4)
#         ;
#
#
#
#
#             var marker_868ebf42995eebdc243c65110889d001 = L.marker(
#                 [43.4964012, 5.3943974],
#                 {}
#             ).addTo(map_1cd90a7dcbc4860479cf19c16cfee411);
#
#
#         var popup_2a385d7191a03597041cda4682751c70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5eb05e2078220447cf
